# %%
#  Dependacies

from config import weather_api_key, g_key
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from datetime import datetime
import time
from scipy.stats import linregress
import gmaps

# %%
lats = np.random.uniform(-90, 90, size=2000)
lngs = np.random.uniform(-180, 180, size=2000)

coordinates = zip(lats, lngs)
cities = []


for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="

city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    
    city_url = url + weather_api_key + "&q=" + city.replace(" ", "+")
    
    try:
        city_weather = requests.get(city_url).json()
        
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime("%Y-%m-%d %H:%M:%S")

        
        city_data.append({
                          "City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Country": city_country,
                          "Date": city_date
                        })
        
    except KeyError:
        print("City not found. Skipping...")
        continue
        
    print(f"Processing record count {record_count} of set {set_count} | {city}")
    record_count += 1
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing record count 1 of set 1 | jamestown
# City not found. Skipping...
# Processing record count 2 of set 1 | bethel
# Processing record count 3 of set 1 | torbay
# City not found. Skipping...
# Processing record count 4 of set 1 | albany
# Processing record count 5 of set 1 | cidreira
# City not found. Skipping...
# Processing record count 6 of set 1 | coahuayana
# Processing record count 7 of set 1 | hilo
# Processing record count 8 of set 1 | noumea
# City not found. Skipping...
# Processing record count 9 of set 1 | puerto ayora
# Processing record count 10 of set 1 | saint george
# Processing record count 11 of set 1 | butaritari
# Processing record count 12 of set 1 | kaitangata
# Processing record count 13 of set 1 | ushuaia
# Processing record count 14 of set 1 | menongue
# Processing record count 15 of set 1 | chapada dos guimaraes
# Processing record count 16 of set 1 | saint-francois
# Processing record count 17 of set 1 | tevaitoa
# Processing record count 18 of set 1 | machali
# Processing record count 19 of set 1 | codrington
# Processing record count 20 of set 1 | busselton
# City not found. Skipping...
# Processing record count 21 of set 1 | podujevo
# Processing record count 22 of set 1 | petropavlovsk-kamchatskiy
# Processing record count 23 of set 1 | atuona
# Processing record count 24 of set 1 | manbij
# City not found. Skipping...
# Processing record count 25 of set 1 | ayan
# Processing record count 26 of set 1 | acarau
# Processing record count 27 of set 1 | rikitea
# Processing record count 28 of set 1 | fortuna
# Processing record count 29 of set 1 | erenhot
# Processing record count 30 of set 1 | kirakira
# Processing record count 31 of set 1 | port alfred
# Processing record count 32 of set 1 | bluff
# Processing record count 33 of set 1 | burns lake
# Processing record count 34 of set 1 | nurota
# Processing record count 35 of set 1 | bojnurd
# Processing record count 36 of set 1 | buchanan
# Processing record count 37 of set 1 | sao joao da barra
# Processing record count 38 of set 1 | qorveh
# City not found. Skipping...
# Processing record count 39 of set 1 | hare bay
# Processing record count 40 of set 1 | soderhamn
# Processing record count 41 of set 1 | matara
# Processing record count 42 of set 1 | zhigansk
# Processing record count 43 of set 1 | arraial do cabo
# Processing record count 1 of set 2 | pacific grove
# Processing record count 2 of set 2 | neuquen
# Processing record count 3 of set 2 | sao filipe
# Processing record count 4 of set 2 | provideniya
# Processing record count 5 of set 2 | madera
# Processing record count 6 of set 2 | guerrero negro
# Processing record count 7 of set 2 | cape town
# Processing record count 8 of set 2 | aykhal
# Processing record count 9 of set 2 | pevek
# Processing record count 10 of set 2 | vestmannaeyjar
# Processing record count 11 of set 2 | mpongwe
# Processing record count 12 of set 2 | port augusta
# Processing record count 13 of set 2 | punta arenas
# Processing record count 14 of set 2 | geraldton
# Processing record count 15 of set 2 | khatanga
# Processing record count 16 of set 2 | ponta do sol
# Processing record count 17 of set 2 | kruisfontein
# Processing record count 18 of set 2 | samarai
# City not found. Skipping...
# Processing record count 19 of set 2 | qaqortoq
# Processing record count 20 of set 2 | lebu
# Processing record count 21 of set 2 | kudahuvadhoo
# Processing record count 22 of set 2 | bengkulu
# Processing record count 23 of set 2 | san patricio
# City not found. Skipping...
# City not found. Skipping...
# Processing record count 24 of set 2 | tasiilaq
# Processing record count 25 of set 2 | vaini
# Processing record count 26 of set 2 | havoysund
# Processing record count 27 of set 2 | bambous virieux
# Processing record count 28 of set 2 | luanda
# Processing record count 29 of set 2 | toora-khem
# Processing record count 30 of set 2 | hithadhoo
# Processing record count 31 of set 2 | bloomfield
# Processing record count 32 of set 2 | faanui
# City not found. Skipping...
# Processing record count 33 of set 2 | severo-kurilsk
# Processing record count 34 of set 2 | chuy
# Processing record count 35 of set 2 | saskylakh
# Processing record count 36 of set 2 | cabo san lucas
# Processing record count 37 of set 2 | xam nua
# Processing record count 38 of set 2 | zacualtipan
# Processing record count 39 of set 2 | kinablangan
# Processing record count 40 of set 2 | pangnirtung
# Processing record count 41 of set 2 | karaman
# Processing record count 42 of set 2 | talnakh
# Processing record count 43 of set 2 | santa isabel do rio negro
# City not found. Skipping...
# Processing record count 44 of set 2 | fundao
# Processing record count 45 of set 2 | barrow
# Processing record count 1 of set 3 | narsaq
# Processing record count 2 of set 3 | leshukonskoye
# Processing record count 3 of set 3 | mataura
# Processing record count 4 of set 3 | the valley
# Processing record count 5 of set 3 | salalah
# City not found. Skipping...
# Processing record count 6 of set 3 | sabang
# Processing record count 7 of set 3 | ovalle
# Processing record count 8 of set 3 | yinchuan
# Processing record count 9 of set 3 | manokwari
# Processing record count 10 of set 3 | kyra
# Processing record count 11 of set 3 | kapaa
# Processing record count 12 of set 3 | santa cruz
# Processing record count 13 of set 3 | chunhuhub
# Processing record count 14 of set 3 | talas
# Processing record count 15 of set 3 | ambilobe
# Processing record count 16 of set 3 | bilma
# Processing record count 17 of set 3 | tual
# City not found. Skipping...
# Processing record count 18 of set 3 | hobart
# Processing record count 19 of set 3 | dakar
# Processing record count 20 of set 3 | nikolskoye
# Processing record count 21 of set 3 | soroti
# Processing record count 22 of set 3 | broome
# Processing record count 23 of set 3 | saint-pierre
# Processing record count 24 of set 3 | ribeira grande
# Processing record count 25 of set 3 | qaanaaq
# Processing record count 26 of set 3 | bandarbeyla
# Processing record count 27 of set 3 | kavieng
# Processing record count 28 of set 3 | carnarvon
# Processing record count 29 of set 3 | naze
# Processing record count 30 of set 3 | bauchi
# Processing record count 31 of set 3 | amazar
# Processing record count 32 of set 3 | lodwar
# Processing record count 33 of set 3 | upernavik
# Processing record count 34 of set 3 | abu samrah
# Processing record count 35 of set 3 | jardim
# Processing record count 36 of set 3 | saint-joseph
# Processing record count 37 of set 3 | kalat
# Processing record count 38 of set 3 | yacuiba
# Processing record count 39 of set 3 | hermanus
# Processing record count 40 of set 3 | padang
# Processing record count 41 of set 3 | anito
# Processing record count 42 of set 3 | nome
# Processing record count 43 of set 3 | basoko
# Processing record count 44 of set 3 | thompson
# Processing record count 45 of set 3 | san quintin
# Processing record count 46 of set 3 | lompoc
# Processing record count 47 of set 3 | tuscaloosa
# Processing record count 48 of set 3 | berlevag
# Processing record count 1 of set 4 | korla
# Processing record count 2 of set 4 | mahibadhoo
# Processing record count 3 of set 4 | alexandria
# Processing record count 4 of set 4 | tucuma
# Processing record count 5 of set 4 | avarua
# Processing record count 6 of set 4 | suntar
# Processing record count 7 of set 4 | bosaso
# Processing record count 8 of set 4 | miri
# Processing record count 9 of set 4 | westlock
# City not found. Skipping...
# Processing record count 10 of set 4 | tuatapere
# Processing record count 11 of set 4 | san jose de guanipa
# Processing record count 12 of set 4 | wick
# Processing record count 13 of set 4 | caraz
# Processing record count 14 of set 4 | mahebourg
# City not found. Skipping...
# Processing record count 15 of set 4 | bay roberts
# Processing record count 16 of set 4 | katsuura
# Processing record count 17 of set 4 | rantepao
# Processing record count 18 of set 4 | labuhan
# Processing record count 19 of set 4 | byron bay
# Processing record count 20 of set 4 | antofagasta
# Processing record count 21 of set 4 | seddon
# Processing record count 22 of set 4 | ginir
# Processing record count 23 of set 4 | hazorasp
# Processing record count 24 of set 4 | georgetown
# Processing record count 25 of set 4 | semirom
# Processing record count 26 of set 4 | faya
# Processing record count 27 of set 4 | atambua
# City not found. Skipping...
# Processing record count 28 of set 4 | port-gentil
# Processing record count 29 of set 4 | castro
# Processing record count 30 of set 4 | kaohsiung
# Processing record count 31 of set 4 | antalaha
# Processing record count 32 of set 4 | new norfolk
# Processing record count 33 of set 4 | teo
# Processing record count 34 of set 4 | metu
# Processing record count 35 of set 4 | maxixe
# Processing record count 36 of set 4 | viloco
# Processing record count 37 of set 4 | beringovskiy
# Processing record count 38 of set 4 | cherskiy
# Processing record count 39 of set 4 | heishan
# Processing record count 40 of set 4 | ubinskoye
# Processing record count 41 of set 4 | sibolga
# Processing record count 42 of set 4 | husavik
# Processing record count 43 of set 4 | gawler
# Processing record count 44 of set 4 | yar-sale
# Processing record count 45 of set 4 | fare
# Processing record count 46 of set 4 | muravlenko
# Processing record count 47 of set 4 | panaba
# City not found. Skipping...
# Processing record count 1 of set 5 | bredasdorp
# Processing record count 2 of set 5 | pisco
# Processing record count 3 of set 5 | nanortalik
# Processing record count 4 of set 5 | loding
# City not found. Skipping...
# Processing record count 5 of set 5 | changji
# Processing record count 6 of set 5 | acajutla
# Processing record count 7 of set 5 | honningsvag
# Processing record count 8 of set 5 | mackay
# Processing record count 9 of set 5 | kathu
# Processing record count 10 of set 5 | port elizabeth
# Processing record count 11 of set 5 | turukhansk
# Processing record count 12 of set 5 | longyearbyen
# Processing record count 13 of set 5 | valparaiso
# Processing record count 14 of set 5 | moron
# Processing record count 15 of set 5 | yellowknife
# Processing record count 16 of set 5 | kenora
# Processing record count 17 of set 5 | kloulklubed
# Processing record count 18 of set 5 | zyryanka
# Processing record count 19 of set 5 | mayo
# City not found. Skipping...
# Processing record count 20 of set 5 | norman wells
# Processing record count 21 of set 5 | blythe
# Processing record count 22 of set 5 | kodiak
# Processing record count 23 of set 5 | victoria
# Processing record count 24 of set 5 | mar del plata
# Processing record count 25 of set 5 | east london
# Processing record count 26 of set 5 | george
# City not found. Skipping...
# Processing record count 27 of set 5 | jalu
# Processing record count 28 of set 5 | necochea
# Processing record count 29 of set 5 | havre-saint-pierre
# Processing record count 30 of set 5 | marsala
# Processing record count 31 of set 5 | kanye
# Processing record count 32 of set 5 | hualmay
# Processing record count 33 of set 5 | saint-philippe
# Processing record count 34 of set 5 | walvis bay
# Processing record count 35 of set 5 | yorosso
# Processing record count 36 of set 5 | soyo
# Processing record count 37 of set 5 | iquitos
# Processing record count 38 of set 5 | guozhen
# Processing record count 39 of set 5 | miandrivazo
# Processing record count 40 of set 5 | pangkalanbuun
# Processing record count 41 of set 5 | deputatskiy
# Processing record count 42 of set 5 | fairbanks
# City not found. Skipping...
# Processing record count 43 of set 5 | dikson
# City not found. Skipping...
# Processing record count 44 of set 5 | usakos
# Processing record count 1 of set 6 | melbu
# Processing record count 2 of set 6 | pathein
# Processing record count 3 of set 6 | la cumbre
# Processing record count 4 of set 6 | ketchikan
# Processing record count 5 of set 6 | flinders
# Processing record count 6 of set 6 | sinnamary
# City not found. Skipping...
# Processing record count 7 of set 6 | biak
# Processing record count 8 of set 6 | itarema
# Processing record count 9 of set 6 | yingcheng
# City not found. Skipping...
# City not found. Skipping...
# Processing record count 10 of set 6 | tilichiki
# Processing record count 11 of set 6 | sosnogorsk
# Processing record count 12 of set 6 | pangody
# Processing record count 13 of set 6 | constitucion
# Processing record count 14 of set 6 | souillac
# Processing record count 15 of set 6 | rocha
# Processing record count 16 of set 6 | chokurdakh
# Processing record count 17 of set 6 | alice springs
# Processing record count 18 of set 6 | raudeberg
# Processing record count 19 of set 6 | juneau
# Processing record count 20 of set 6 | port-cartier
# Processing record count 21 of set 6 | asau
# Processing record count 22 of set 6 | chitradurga
# Processing record count 23 of set 6 | tyulyachi
# Processing record count 24 of set 6 | kutum
# City not found. Skipping...
# Processing record count 25 of set 6 | ilulissat
# Processing record count 26 of set 6 | puerto leguizamo
# Processing record count 27 of set 6 | kushima
# Processing record count 28 of set 6 | gonbad-e qabus
# Processing record count 29 of set 6 | dicabisagan
# Processing record count 30 of set 6 | siavonga
# Processing record count 31 of set 6 | esperance
# Processing record count 32 of set 6 | waddan
# Processing record count 33 of set 6 | slave lake
# Processing record count 34 of set 6 | cayenne
# Processing record count 35 of set 6 | airai
# Processing record count 36 of set 6 | wanning
# City not found. Skipping...
# Processing record count 37 of set 6 | whitianga
# Processing record count 38 of set 6 | riyadh
# Processing record count 39 of set 6 | tiksi
# City not found. Skipping...
# Processing record count 40 of set 6 | port hedland
# City not found. Skipping...
# Processing record count 41 of set 6 | ostrovnoy
# Processing record count 42 of set 6 | egvekinot
# Processing record count 43 of set 6 | san carlos de bariloche
# Processing record count 1 of set 7 | nouadhibou
# Processing record count 2 of set 7 | dhidhdhoo
# Processing record count 3 of set 7 | mapastepec
# Processing record count 4 of set 7 | adrar
# City not found. Skipping...
# Processing record count 5 of set 7 | havelock
# Processing record count 6 of set 7 | severnyy
# Processing record count 7 of set 7 | tornio
# Processing record count 8 of set 7 | moose factory
# Processing record count 9 of set 7 | gambela
# Processing record count 10 of set 7 | ambon
# Processing record count 11 of set 7 | hinton
# Processing record count 12 of set 7 | itum-kale
# Processing record count 13 of set 7 | benjamin hill
# Processing record count 14 of set 7 | comodoro rivadavia
# Processing record count 15 of set 7 | klaksvik
# Processing record count 16 of set 7 | bluefields
# Processing record count 17 of set 7 | sorland
# Processing record count 18 of set 7 | trelew
# Processing record count 19 of set 7 | straumen
# Processing record count 20 of set 7 | pitimbu
# Processing record count 21 of set 7 | arbazh
# Processing record count 22 of set 7 | malakal
# Processing record count 23 of set 7 | kulykiv
# Processing record count 24 of set 7 | dali
# Processing record count 25 of set 7 | saint-denis
# Processing record count 26 of set 7 | borogontsy
# City not found. Skipping...
# Processing record count 27 of set 7 | yuanping
# Processing record count 28 of set 7 | ust-maya
# Processing record count 29 of set 7 | bataipora
# Processing record count 30 of set 7 | zhigalovo
# Processing record count 31 of set 7 | benguela
# Processing record count 32 of set 7 | coquimbo
# Processing record count 33 of set 7 | kjollefjord
# Processing record count 34 of set 7 | bathsheba
# Processing record count 35 of set 7 | milkovo
# Processing record count 36 of set 7 | eureka
# Processing record count 37 of set 7 | paro
# Processing record count 38 of set 7 | ahipara
# Processing record count 39 of set 7 | mormugao
# Processing record count 40 of set 7 | hudiksvall
# Processing record count 41 of set 7 | muros
# Processing record count 42 of set 7 | douentza
# Processing record count 43 of set 7 | nara
# Processing record count 44 of set 7 | balaguer
# Processing record count 45 of set 7 | xai-xai
# Processing record count 46 of set 7 | chumikan
# Processing record count 47 of set 7 | roald
# Processing record count 48 of set 7 | hasaki
# Processing record count 1 of set 8 | paamiut
# Processing record count 2 of set 8 | jumla
# Processing record count 3 of set 8 | sherlovaya gora
# Processing record count 4 of set 8 | mackenzie
# Processing record count 5 of set 8 | yumen
# City not found. Skipping...
# Processing record count 6 of set 8 | mahajanga
# Processing record count 7 of set 8 | tessalit
# Processing record count 8 of set 8 | puerto escondido
# Processing record count 9 of set 8 | lavrentiya
# Processing record count 10 of set 8 | luderitz
# Processing record count 11 of set 8 | concepcion del oro
# Processing record count 12 of set 8 | balykshi
# Processing record count 13 of set 8 | kargasok
# Processing record count 14 of set 8 | mbanza-ngungu
# Processing record count 15 of set 8 | whitley bay
# Processing record count 16 of set 8 | burnie
# Processing record count 17 of set 8 | los llanos de aridane
# Processing record count 18 of set 8 | viedma
# Processing record count 19 of set 8 | vao
# Processing record count 20 of set 8 | tabas
# Processing record count 21 of set 8 | henties bay
# Processing record count 22 of set 8 | magomeni
# Processing record count 23 of set 8 | port blair
# Processing record count 24 of set 8 | san cristobal
# Processing record count 25 of set 8 | ampanihy
# Processing record count 26 of set 8 | mugur-aksy
# Processing record count 27 of set 8 | sovetskaya gavan
# Processing record count 28 of set 8 | batemans bay
# City not found. Skipping...
# Processing record count 29 of set 8 | galveston
# Processing record count 30 of set 8 | sao felix do xingu
# Processing record count 31 of set 8 | tukums
# Processing record count 32 of set 8 | tuktoyaktuk
# City not found. Skipping...
# Processing record count 33 of set 8 | rome
# Processing record count 34 of set 8 | brae
# City not found. Skipping...
# Processing record count 35 of set 8 | xining
# Processing record count 36 of set 8 | lasa
# Processing record count 37 of set 8 | hillsborough
# Processing record count 38 of set 8 | talakan
# Processing record count 39 of set 8 | maanshan
# Processing record count 40 of set 8 | lorengau
# Processing record count 41 of set 8 | olafsvik
# Processing record count 42 of set 8 | valence
# Processing record count 43 of set 8 | vardo
# Processing record count 44 of set 8 | touros
# Processing record count 45 of set 8 | nueva londres
# Processing record count 46 of set 8 | porto velho
# Processing record count 1 of set 9 | puerto madryn
# Processing record count 2 of set 9 | nizhniy tsasuchey
# Processing record count 3 of set 9 | zhezkazgan
# Processing record count 4 of set 9 | makakilo city
# Processing record count 5 of set 9 | komsomolskiy
# Processing record count 6 of set 9 | avera
# Processing record count 7 of set 9 | xihe
# Processing record count 8 of set 9 | port lincoln
# Processing record count 9 of set 9 | omboue
# Processing record count 10 of set 9 | tumaco
# Processing record count 11 of set 9 | chimoio
# Processing record count 12 of set 9 | koslan
# Processing record count 13 of set 9 | la ronge
# Processing record count 14 of set 9 | del rio
# Processing record count 15 of set 9 | okhotsk
# Processing record count 16 of set 9 | astana
# City not found. Skipping...
# Processing record count 17 of set 9 | jiaojiang
# Processing record count 18 of set 9 | saint anthony
# Processing record count 19 of set 9 | launceston
# Processing record count 20 of set 9 | hamilton
# Processing record count 21 of set 9 | tambacounda
# Processing record count 22 of set 9 | belaya gora
# Processing record count 23 of set 9 | cochrane
# Processing record count 24 of set 9 | thinadhoo
# Processing record count 25 of set 9 | nelson bay
# Processing record count 26 of set 9 | aden
# Processing record count 27 of set 9 | grindavik
# Processing record count 28 of set 9 | bowen
# Processing record count 29 of set 9 | east cleveland
# Processing record count 30 of set 9 | saint-georges
# Processing record count 31 of set 9 | darhan
# Processing record count 32 of set 9 | sung noen
# Processing record count 33 of set 9 | opuwo
# Processing record count 34 of set 9 | maraba
# Processing record count 35 of set 9 | jurm
# Processing record count 36 of set 9 | lahat
# City not found. Skipping...
# Processing record count 37 of set 9 | saldanha
# Processing record count 38 of set 9 | kongolo
# City not found. Skipping...
# Processing record count 39 of set 9 | stokmarknes
# Processing record count 40 of set 9 | panna
# Processing record count 41 of set 9 | kassala
# Processing record count 42 of set 9 | onverwacht
# Processing record count 43 of set 9 | port hardy
# Processing record count 44 of set 9 | tirau
# Processing record count 45 of set 9 | townsville
# Processing record count 46 of set 9 | pyu
# Processing record count 47 of set 9 | penzance
# Processing record count 1 of set 10 | gallup
# Processing record count 2 of set 10 | torbat-e jam
# Processing record count 3 of set 10 | barabinsk
# Processing record count 4 of set 10 | zhangye
# Processing record count 5 of set 10 | zomin
# Processing record count 6 of set 10 | alamogordo
# Processing record count 7 of set 10 | jamame
# Processing record count 8 of set 10 | sile
# Processing record count 9 of set 10 | boende
# Processing record count 10 of set 10 | leh
# Processing record count 11 of set 10 | miyang
# Processing record count 12 of set 10 | hays
# Processing record count 13 of set 10 | ondangwa
# Processing record count 14 of set 10 | harwich
# Processing record count 15 of set 10 | hofn
# Processing record count 16 of set 10 | muisne
# Processing record count 17 of set 10 | flin flon
# Processing record count 18 of set 10 | bumba
# Processing record count 19 of set 10 | palu
# Processing record count 20 of set 10 | yarkovo
# Processing record count 21 of set 10 | vallenar
# Processing record count 22 of set 10 | gwadar
# Processing record count 23 of set 10 | srednekolymsk
# City not found. Skipping...
# Processing record count 24 of set 10 | margate
# Processing record count 25 of set 10 | genhe
# Processing record count 26 of set 10 | waingapu
# Processing record count 27 of set 10 | vicuna
# Processing record count 28 of set 10 | dourbali
# Processing record count 29 of set 10 | fougamou
# Processing record count 30 of set 10 | napasar
# Processing record count 31 of set 10 | saint simons
# Processing record count 32 of set 10 | clyde river
# Processing record count 33 of set 10 | vestmanna
# Processing record count 34 of set 10 | bakel
# Processing record count 35 of set 10 | araxa
# Processing record count 36 of set 10 | college
# City not found. Skipping...
# Processing record count 37 of set 10 | yakovlevo
# City not found. Skipping...
# Processing record count 38 of set 10 | poso
# Processing record count 39 of set 10 | limulunga
# Processing record count 40 of set 10 | linjiang
# Processing record count 41 of set 10 | mount isa
# Processing record count 42 of set 10 | severodvinsk
# Processing record count 43 of set 10 | nyurba
# Processing record count 44 of set 10 | sisimiut
# Processing record count 45 of set 10 | nkhotakota
# Processing record count 46 of set 10 | assens
# Processing record count 47 of set 10 | sechura
# City not found. Skipping...
# Processing record count 1 of set 11 | hammerfest
# Processing record count 2 of set 11 | ongandjera
# Processing record count 3 of set 11 | rio grande
# Processing record count 4 of set 11 | maumere
# Processing record count 5 of set 11 | denpasar
# Processing record count 6 of set 11 | basco
# Processing record count 7 of set 11 | nybro
# Processing record count 8 of set 11 | port macquarie
# Processing record count 9 of set 11 | khorixas
# Processing record count 10 of set 11 | almoloya
# Processing record count 11 of set 11 | minab
# Processing record count 12 of set 11 | harper
# City not found. Skipping...
# Processing record count 13 of set 11 | mount gambier
# Processing record count 14 of set 11 | bubaque
# Processing record count 15 of set 11 | ahar
# Processing record count 16 of set 11 | kenai
# Processing record count 17 of set 11 | santa rosa
# Processing record count 18 of set 11 | gamba
# Processing record count 19 of set 11 | mitsamiouli
# Processing record count 20 of set 11 | pandamatenga
# Processing record count 21 of set 11 | rovaniemi
# City not found. Skipping...
# Processing record count 22 of set 11 | robore
# Processing record count 23 of set 11 | seoul
# Processing record count 24 of set 11 | cao bang
# City not found. Skipping...
# Processing record count 25 of set 11 | ahuimanu
# Processing record count 26 of set 11 | vaxjo
# Processing record count 27 of set 11 | kabanga
# Processing record count 28 of set 11 | camacha
# Processing record count 29 of set 11 | san andres
# Processing record count 30 of set 11 | ojinaga
# Processing record count 31 of set 11 | jaynagar-majilpur
# Processing record count 32 of set 11 | teya
# Processing record count 33 of set 11 | port shepstone
# City not found. Skipping...
# Processing record count 34 of set 11 | balkanabat
# City not found. Skipping...
# Processing record count 35 of set 11 | natchitoches
# Processing record count 36 of set 11 | iqaluit
# Processing record count 37 of set 11 | kaka
# Processing record count 38 of set 11 | mungaa
# Processing record count 39 of set 11 | haines junction
# Processing record count 40 of set 11 | blackwater
# Processing record count 41 of set 11 | erzin
# Processing record count 42 of set 11 | buala
# Processing record count 43 of set 11 | pochutla
# Processing record count 44 of set 11 | smithers
# Processing record count 1 of set 12 | epiniana
# Processing record count 2 of set 12 | ulaangom
# Processing record count 3 of set 12 | kizukuri
# Processing record count 4 of set 12 | dwarka
# Processing record count 5 of set 12 | lagoa
# Processing record count 6 of set 12 | takanabe
# Processing record count 7 of set 12 | russell
# Processing record count 8 of set 12 | honiara
# Processing record count 9 of set 12 | solnechnyy
# Processing record count 10 of set 12 | bereda
# Processing record count 11 of set 12 | simao
# City not found. Skipping...
# Processing record count 12 of set 12 | sabha
# Processing record count 13 of set 12 | sitka
# Processing record count 14 of set 12 | magadan
# Processing record count 15 of set 12 | pioner
# Processing record count 16 of set 12 | banda aceh
# Processing record count 17 of set 12 | parati
# Processing record count 18 of set 12 | kahului
# Processing record count 19 of set 12 | dingle
# Processing record count 20 of set 12 | gorontalo
# City not found. Skipping...
# Processing record count 21 of set 12 | markova
# Processing record count 22 of set 12 | ancud
# Processing record count 23 of set 12 | barra do garcas
# Processing record count 24 of set 12 | pontianak
# Processing record count 25 of set 12 | enshi
# Processing record count 26 of set 12 | lazaro cardenas
# Processing record count 27 of set 12 | eyl
# Processing record count 28 of set 12 | birjand
# Processing record count 29 of set 12 | kuopio
# Processing record count 30 of set 12 | gijon
# Processing record count 31 of set 12 | kasane
# Processing record count 32 of set 12 | kapit
# Processing record count 33 of set 12 | pak phanang
# City not found. Skipping...
# Processing record count 34 of set 12 | nalut
# Processing record count 35 of set 12 | khasan
# Processing record count 36 of set 12 | cabedelo
# Processing record count 37 of set 12 | gorgan
# Processing record count 38 of set 12 | atbasar
# Processing record count 39 of set 12 | severo-yeniseyskiy
# Processing record count 40 of set 12 | gazli
# Processing record count 41 of set 12 | warri
# Processing record count 42 of set 12 | fomboni
# Processing record count 43 of set 12 | mercedes
# Processing record count 44 of set 12 | nuuk
# Processing record count 45 of set 12 | dunedin
# Processing record count 46 of set 12 | namibe
# Processing record count 47 of set 12 | otsuki
# Processing record count 1 of set 13 | matamoros
# Processing record count 2 of set 13 | quatre cocos
# City not found. Skipping...
# Processing record count 3 of set 13 | stromness
# Processing record count 4 of set 13 | ponta delgada
# Processing record count 5 of set 13 | acapulco
# Processing record count 6 of set 13 | murgab
# Processing record count 7 of set 13 | ishii
# Processing record count 8 of set 13 | fuxin
# Processing record count 9 of set 13 | colorado springs
# Processing record count 10 of set 13 | ghanzi
# Processing record count 11 of set 13 | soe
# Processing record count 12 of set 13 | san angelo
# Processing record count 13 of set 13 | santa cecilia
# Processing record count 14 of set 13 | timra
# Processing record count 15 of set 13 | beira
# Processing record count 16 of set 13 | porto novo
# Processing record count 17 of set 13 | kyaikto
# Processing record count 18 of set 13 | hami
# Processing record count 19 of set 13 | fougeres
# Processing record count 20 of set 13 | roma
# Processing record count 21 of set 13 | midyat
# Processing record count 22 of set 13 | rawson
# Processing record count 23 of set 13 | along
# Processing record count 24 of set 13 | ulaanbaatar
# City not found. Skipping...
# Processing record count 25 of set 13 | slavutych
# Processing record count 26 of set 13 | san
# City not found. Skipping...
# Processing record count 27 of set 13 | akdepe
# Processing record count 28 of set 13 | lichtenstein
# Processing record count 29 of set 13 | cradock
# City not found. Skipping...
# Processing record count 30 of set 13 | veraval
# Processing record count 31 of set 13 | la vergne
# Processing record count 32 of set 13 | gat
# Processing record count 33 of set 13 | yarmouth
# Processing record count 34 of set 13 | oranjemund
# Processing record count 35 of set 13 | karratha
# Processing record count 36 of set 13 | pafos
# Processing record count 37 of set 13 | beidao
# Processing record count 38 of set 13 | iisalmi
# Processing record count 39 of set 13 | novouzensk
# Processing record count 40 of set 13 | tezu
# Processing record count 41 of set 13 | rincon
# Processing record count 42 of set 13 | jihlava
# Processing record count 43 of set 13 | yenagoa
# Processing record count 44 of set 13 | gillette
# Processing record count 45 of set 13 | paso de los toros
# Processing record count 46 of set 13 | zabol
# Processing record count 1 of set 14 | shimoda
# Processing record count 2 of set 14 | lazarev
# Processing record count 3 of set 14 | seymchan
# Processing record count 4 of set 14 | sioux lookout
# Processing record count 5 of set 14 | sebring
# Processing record count 6 of set 14 | manoel urbano
# Processing record count 7 of set 14 | camacupa
# Processing record count 8 of set 14 | nhulunbuy
# Processing record count 9 of set 14 | ornskoldsvik
# Processing record count 10 of set 14 | gravdal
# Processing record count 11 of set 14 | mutare
# Processing record count 12 of set 14 | mokhsogollokh
# Processing record count 13 of set 14 | alenquer
# Processing record count 14 of set 14 | bani
# Processing record count 15 of set 14 | kuito
# City not found. Skipping...
# Processing record count 16 of set 14 | marsh harbour
# Processing record count 17 of set 14 | anadyr
# Processing record count 18 of set 14 | tarko-sale
# Processing record count 19 of set 14 | bilibino
# Processing record count 20 of set 14 | todos santos
# Processing record count 21 of set 14 | jackson
# Processing record count 22 of set 14 | polewali
# Processing record count 23 of set 14 | half moon bay
# Processing record count 24 of set 14 | bayji
# Processing record count 25 of set 14 | arman
# Processing record count 26 of set 14 | auki
# Processing record count 27 of set 14 | wad rawah
# Processing record count 28 of set 14 | isangel
# Processing record count 29 of set 14 | karaton
# Processing record count 30 of set 14 | inuvik
# City not found. Skipping...
# Processing record count 31 of set 14 | ulma
# Processing record count 32 of set 14 | siocon
# Processing record count 33 of set 14 | oistins
# Processing record count 34 of set 14 | grand gaube
# Processing record count 35 of set 14 | ferme-neuve
# Processing record count 36 of set 14 | arlit
# Processing record count 37 of set 14 | matelandia
# Processing record count 38 of set 14 | san rafael
# Processing record count 39 of set 14 | lethem
# Processing record count 40 of set 14 | kavaratti
# Processing record count 41 of set 14 | leningradskiy
# City not found. Skipping...
# Processing record count 42 of set 14 | guararapes
# Processing record count 43 of set 14 | languyan
# Processing record count 44 of set 14 | puerto lopez
# Processing record count 45 of set 14 | mangrol
# Processing record count 46 of set 14 | nikolayevka
# Processing record count 47 of set 14 | taksimo
# Processing record count 1 of set 15 | te anau
# Processing record count 2 of set 15 | agadez
# Processing record count 3 of set 15 | farafangana
# Processing record count 4 of set 15 | maragogi
# Processing record count 5 of set 15 | vila franca do campo
# Processing record count 6 of set 15 | gourcy
# City not found. Skipping...
# Processing record count 7 of set 15 | prince rupert
# Processing record count 8 of set 15 | tonekabon
# Processing record count 9 of set 15 | san felipe
# Processing record count 10 of set 15 | ipixuna
# Processing record count 11 of set 15 | perth
# Processing record count 12 of set 15 | kodinsk
# Processing record count 13 of set 15 | saryg-sep
# Processing record count 14 of set 15 | kurilsk
# Processing record count 15 of set 15 | merauke
# Processing record count 16 of set 15 | kanigoro
# Processing record count 17 of set 15 | agadir
# Processing record count 18 of set 15 | gerede
# Processing record count 19 of set 15 | zhuhai
# City not found. Skipping...
# Processing record count 20 of set 15 | bintulu
# Processing record count 21 of set 15 | itoman
# Processing record count 22 of set 15 | cururupu
# Processing record count 23 of set 15 | khuzhir
# Processing record count 24 of set 15 | carauari
# Processing record count 25 of set 15 | rumuruti
# Processing record count 26 of set 15 | culebra
# City not found. Skipping...
# Processing record count 27 of set 15 | labrea
# Processing record count 28 of set 15 | shache
# Processing record count 29 of set 15 | gayeri
# Processing record count 30 of set 15 | elko
# City not found. Skipping...
# Processing record count 31 of set 15 | bitung
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]

output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
