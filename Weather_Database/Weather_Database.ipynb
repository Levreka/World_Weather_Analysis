# %% [markdown]
# # Deliverable 1: Retrieve Weather Data

# %%
#  importing our Dependacies
from config import weather_api_key, g_key
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from datetime import datetime

# %%
# creating our longituted and latituted for 2000
lats = np.random.uniform(-90, 90, size=2000)
lngs = np.random.uniform(-180, 180, size=2000)
# variable to hold our cordinates
coordinates = zip(lats, lngs)
# variable to hold our cities
cities = []

# looping to get the nearest city using Citipy module
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)

# %%
# # Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes. this due to restrictions
#     in the free version of the Weather map API 
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
     # Create endpoint URL with each city.
    city_url = url + weather_api_key + "&q=" + city.replace(" ", "+")
    # Assign variables for each piece of data we need.
# Add the data to the cities list in a dictionary format.  
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
         # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
         # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime("%Y-%m-%d %H:%M:%S")

        # Append the city information into city_data list.
        city_data.append({
                          "City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Country": city_country,
                          "Date": city_date
                        })
      # If an error is experienced, skip the city.  
    except KeyError:
        print("City not found. Skipping...")
        continue
     # Log the URL, record, and set numbers and the city.    
    print(f"Processing record count {record_count} of set {set_count} | {city}")
#      Add 1 to the record count.
    record_count += 1
# Indicate that Data Loading is complete.   
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing record count 1 of set 1 | kuching
# Processing record count 2 of set 1 | airai
# Processing record count 3 of set 1 | hithadhoo
# Processing record count 4 of set 1 | felanitx
# City not found. Skipping...
# Processing record count 5 of set 1 | salalah
# Processing record count 6 of set 1 | qaqortoq
# Processing record count 7 of set 1 | moron
# Processing record count 8 of set 1 | busselton
# City not found. Skipping...
# Processing record count 9 of set 1 | lagoa
# Processing record count 10 of set 1 | butaritari
# Processing record count 11 of set 1 | jamestown
# Processing record count 12 of set 1 | rikitea
# Processing record count 13 of set 1 | ostrovnoy
# Processing record count 14 of set 1 | tiarei
# Processing record count 15 of set 1 | mahebourg
# Processing record count 16 of set 1 | hervey bay
# Processing record count 17 of set 1 | pemangkat
# Processing record count 18 of set 1 | luderitz
# ...

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
# rearranging the order of the columns in our city_data_df
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Verfying dataset looks the way we intended
city_data_df.head(10)
# Out:
#          City Country                 Date      Lat       Lng  Max Temp  \
# 0     Kuching      MY  2022-10-19 01:06:41   1.5500  110.3333     79.02
# 1       Airai      TL  2022-10-19 01:06:41  -8.9266  125.4092     73.99
# 2   Hithadhoo      MV  2022-10-19 01:06:41  -0.6000   73.0833     81.07
# 3    Felanitx      ES  2022-10-19 01:05:22  39.4696    3.1483     68.13
# 4     Salalah      OM  2022-10-19 01:06:42  17.0151   54.0924     71.69
# 5    Qaqortoq      GL  2022-10-19 01:06:43  60.7167  -46.0333     37.20
# 6       Moron      AR  2022-10-19 01:00:16 -34.6534  -58.6198     67.01
# 7   Busselton      AU  2022-10-19 01:06:43 -33.6500  115.3333     65.26
# 8       Lagoa      PT  2022-10-19 01:06:44  39.0500  -27.9833     63.84
# 9  Butaritari      KI  2022-10-19 01:06:44   3.0707  172.7902     81.41
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        94          20        0.00          few clouds
# 1        60         100        0.87     overcast clouds
# ...
